# %%
# A tuple of integers
numbers = (1, 2, 3, 4, 5)
print(numbers)

# A tuple of strings
fruits = ("apple", "banana", "cherry")
print(fruits)

# A tuple with mixed types
mixed_tuple = (1, "Hello", 3.14, True)
print(mixed_tuple)

# An empty tuple
empty_tuple = ()
print(empty_tuple)

# A tuple with one item (note the comma)
singleton = (1,)
print(singleton)
# Out:
# (1, 2, 3, 4, 5)
# ('apple', 'banana', 'cherry')
# (1, 'Hello', 3.14, True)
# ()
# (1,)

# %%
# This will raise an error
numbers[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-682bb1c97314> in <cell line: 2>()
#       1 # This will raise an error
# ----> 2 numbers[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Unpacking a tuple
x, y, z = (1, 2, 3)
print(x, y, z)  # Output: 1 2 3
# Out:
# 1 2 3

# %%
# Slicing a tuple
print(numbers[1:4])  # Output: (2, 3, 4)
# Out:
# (2, 3, 4)

# %%
print(numbers.count(2))  # Output: 1
print(numbers.index(3))  # Output: 2
# Out:
# 1
# 2
